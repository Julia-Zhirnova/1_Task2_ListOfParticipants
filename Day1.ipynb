# %% [markdown]
# <a href="https://colab.research.google.com/github/Julia-Zhirnova/1_Task2_ListOfParticipants/blob/master/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
pip install opencv-python

# %%
import cv2
from IPython.display import Image

# %%
img = cv2.imread('car.jpg')

# %%
#print(img)
Image('car.jpg')
